# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import datetime as dt
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline 
import seaborn as sns
from scipy import stats
import itertools
#Scikit-Learn for Modeling
from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
train=pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
np.shape(train)
# Out:
# (1017209, 9)

# %%
train['Store'].unique()
# Out:
# array([   1,    2,    3, ..., 1113, 1114, 1115], dtype=int64)

# %%
df=pd.DataFrame(train)

# %%
df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# 5            6          5  2015-07-31   5651        589     1      1
# 6            7          5  2015-07-31  15344       1414     1      1
# 7            8          5  2015-07-31   8492        833     1      1
# 8            9          5  2015-07-31   8565        687     1      1
# 9           10          5  2015-07-31   7185        681     1      1
# 10          11          5  2015-07-31  10457       1236     1      1
# 11          12          5  2015-07-31   8959        962     1      1
# 12          13          5  2015-07-31   8821        568     1      1
# ...

# %%
df.isna().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
df1=df[df['Open']!=0]

# %%
np.shape(df1)
# Out:
# (844392, 9)

# %%
df2=df1[df1['Sales']>0]

# %%
np.shape(df2)
# Out:
# (844338, 9)

# %%
store=pd.read_csv('store.csv')

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df_train=pd.merge(df2,store,on="Store")#merging store data and train data to see more features.

# %%
df_train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'], errors='coerce')

# %%
df_train["Year"] = df_train.Date.dt.year

# %%
df_train["Month"] = df_train.Date.dt.month

# %%
df_train["DayOfWeek"] = df_train.Date.dt.dayofweek

# %%
df_train["WeekOfYear"] = df_train.Date.dt.weekofyear

# %%
df_train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      1          3 2015-07-30   5020        546     1      1            0
# 2      1          2 2015-07-29   4782        523     1      1            0
# 3      1          1 2015-07-28   5011        560     1      1            0
# 4      1          0 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType     ...     CompetitionDistance  \
# 0              1         c     ...                  1270.0
# 1              1         c     ...                  1270.0
# 2              1         c     ...                  1270.0
# 3              1         c     ...                  1270.0
# 4              1         c     ...                  1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
df_train['Year'].unique()
# Out:
# array([2015, 2014, 2013], dtype=int64)

# %%
np.shape(df_train)
# Out:
# (844338, 21)

# %%
sns.countplot(x="Open", hue="DayOfWeek", edgecolor="black", data=df_train)

# %%
ax = sns.barplot(x="DayOfWeek", y="Sales", data=df_train, ci=68)

# %%
df_train[(df_train['Open'] == 1) & (df_train['DayOfWeek'] ==6 )].count() # only 3593 stores are opened during sundays.
# Out:
# Store                        3593
# DayOfWeek                    3593
# Date                         3593
# Sales                        3593
# Customers                    3593
# Open                         3593
# Promo                        3593
# StateHoliday                 3593
# SchoolHoliday                3593
# StoreType                    3593
# Assortment                   3593
# CompetitionDistance          3593
# CompetitionOpenSinceMonth    2144
# CompetitionOpenSinceYear     2144
# Promo2                       3593
# Promo2SinceWeek              1005
# Promo2SinceYear              1005
# PromoInterval                1005
# Year                         3593
# Month                        3593
# WeekOfYear                   3593
# dtype: int64

# %%
df_train['StateHoliday'].unique()
# Out:
# array(['0', 0, 'a', 'b', 'c'], dtype=object)

# %%
df_train['SchoolHoliday'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_train['Assortment'].unique()
# Out:
# array(['a', 'c', 'b'], dtype=object)

# %%
(df_train.groupby(by="StoreType").count().Store.index,df_train.groupby(by="StoreType").count().Store)
# Out:
# (Index(['a', 'b', 'c', 'd'], dtype='object', name='StoreType'), StoreType
#  a    457042
#  b     15560
#  c    112968
#  d    258768
#  Name: Store, dtype: int64)

# %%
fig, axes = plt.subplots(2, 2,figsize=(20,20) )
axes[0,0].bar(df_train.groupby(by="StoreType").count().Store.index,df_train.groupby(by="StoreType").count().Store,color=('red', 'green', 'blue', 'purple'))
axes[0,0].set_title("Number of stores for each type")
axes[0,1].bar(df_train.groupby(by="Assortment").count().Store.index,df_train.groupby(by="Assortment").count().Store,color=( 'orange', 'blue', 'purple'))
axes[0,1].set_title("Number of stores for each Assortment")
axes[1,0].bar(df_train.groupby(by="StoreType").count().Store.index,df_train.groupby(by="StoreType").sum().Sales/1e9,color=( 'green', 'blue', 'red','orange'))
axes[1,0].set_title("Total Sales for each store in Billions")
axes[1,1].bar(df_train.groupby(by="StoreType").count().Store.index,df_train.groupby(by="StoreType").sum().Customers/1e6,color=( 'blue', 'orange', 'red','green'))
axes[1,1].set_title("Total number of customers  for each store in millions")
# Out:
# Text(0.5, 1.0, 'Total number of customers  for each store in millions')

# %%
ax = sns.barplot(x="Promo", y="Sales", data=df_train)

# %%
ax = sns.barplot(x="Promo2", y="Sales", data=df_train)

# %%
df_train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      1          3 2015-07-30   5020        546     1      1            0
# 2      1          2 2015-07-29   4782        523     1      1            0
# 3      1          1 2015-07-28   5011        560     1      1            0
# 4      1          0 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType     ...     CompetitionDistance  \
# 0              1         c     ...                  1270.0
# 1              1         c     ...                  1270.0
# 2              1         c     ...                  1270.0
# 3              1         c     ...                  1270.0
# 4              1         c     ...                  1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
sns.barplot(x="Year", y="Sales", data=df_train, edgecolor="black")

# %%
average_sales= df_train.groupby("Month")["Sales"].mean()

# %%
average_sales
# Out:
# Month
# 1     6564.298651
# 2     6589.494012
# 3     6976.817749
# 4     7046.659509
# 5     7106.808038
# 6     7001.402127
# 7     6953.575827
# 8     6649.229053
# 9     6547.469104
# 10    6602.967255
# 11    7188.554250
# 12    8608.956661
# Name: Sales, dtype: float64

# %%
average_sales_year= df_train.groupby("Date")["Sales"].mean()

# %%
sns.catplot(x="StateHoliday", y="Sales", data=df_train,jitter=False)

# %%
df_train.drop(['Date'], axis=1)
# Out:
#         Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0           1          4   5263        555     1      1            0
# 1           1          3   5020        546     1      1            0
# 2           1          2   4782        523     1      1            0
# 3           1          1   5011        560     1      1            0
# 4           1          0   6102        612     1      1            0
# 5           1          5   4364        500     1      0            0
# 6           1          4   3706        459     1      0            0
# 7           1          3   3769        503     1      0            0
# 8           1          2   3464        463     1      0            0
# 9           1          1   3558        469     1      0            0
# 10          1          0   4395        526     1      0            0
# 11          1          5   4406        512     1      0            0
# 12          1          4   4852        519     1      1            0
# ...

# %%
df_train.pop('Date')
# Out:
# 0        2015-07-31
# 1        2015-07-30
# 2        2015-07-29
# 3        2015-07-28
# 4        2015-07-27
# 5        2015-07-25
# 6        2015-07-24
# 7        2015-07-23
# 8        2015-07-22
# 9        2015-07-21
# 10       2015-07-20
# 11       2015-07-18
# 12       2015-07-17
# 13       2015-07-16
# 14       2015-07-15
# 15       2015-07-14
# 16       2015-07-13
# 17       2015-07-11
# 18       2015-07-10
# 19       2015-07-09
# 20       2015-07-08
# 21       2015-07-07
# 22       2015-07-06
# 23       2015-07-04
# 24       2015-07-03
# 25       2015-07-02
# 26       2015-07-01
# 27       2015-06-30
# 28       2015-06-29
# 29       2015-06-27
#             ...
# 844308   2013-02-05
# 844309   2013-02-04
# 844310   2013-02-02
# 844311   2013-02-01
# 844312   2013-01-31
# 844313   2013-01-30
# 844314   2013-01-29
# 844315   2013-01-28
# 844316   2013-01-26
# 844317   2013-01-25
# 844318   2013-01-24
# 844319   2013-01-23
# 844320   2013-01-22
# 844321   2013-01-21
# ...

# %%
sns.barplot(x="SchoolHoliday", y="Sales", data=df_train, edgecolor="black")# Sales isn not influenced muych by schoosns.barplot(l goliday. So we can think of removing school holiday from the features.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 844338 entries, 0 to 844337
# Data columns (total 20 columns):
# Store                        844338 non-null int64
# DayOfWeek                    844338 non-null int64
# Sales                        844338 non-null int64
# Customers                    844338 non-null int64
# Open                         844338 non-null int64
# Promo                        844338 non-null int64
# StateHoliday                 844338 non-null object
# SchoolHoliday                844338 non-null int64
# StoreType                    844338 non-null object
# Assortment                   844338 non-null object
# CompetitionDistance          842152 non-null float64
# CompetitionOpenSinceMonth    575738 non-null float64
# CompetitionOpenSinceYear     575738 non-null float64
# Promo2                       844338 non-null int64
# Promo2SinceWeek              421046 non-null float64
# Promo2SinceYear              421046 non-null float64
# ...

# %%
plt.figure(figsize=(20,20))

plt.scatter(x="Customers",y="Sales", data=df_train)
plt.xlabel("Customers")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
sns.catplot(x="StoreType",y="Sales",data=df_train)# sales for different types of stores.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 844338 entries, 0 to 844337
# Data columns (total 20 columns):
# Store                        844338 non-null int64
# DayOfWeek                    844338 non-null int64
# Sales                        844338 non-null int64
# Customers                    844338 non-null int64
# Open                         844338 non-null int64
# Promo                        844338 non-null int64
# StateHoliday                 844338 non-null object
# SchoolHoliday                844338 non-null int64
# StoreType                    844338 non-null object
# Assortment                   844338 non-null object
# CompetitionDistance          842152 non-null float64
# CompetitionOpenSinceMonth    575738 non-null float64
# CompetitionOpenSinceYear     575738 non-null float64
# Promo2                       844338 non-null int64
# Promo2SinceWeek              421046 non-null float64
# Promo2SinceYear              421046 non-null float64
# ...

# %%
df_train.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2186
# CompetitionOpenSinceMonth    268600
# CompetitionOpenSinceYear     268600
# Promo2                            0
# Promo2SinceWeek              423292
# Promo2SinceYear              423292
# PromoInterval                423292
# Year                              0
# Month                             0
# WeekOfYear                        0
# dtype: int64

# %%
df_train['CompetitionDistance'].fillna(df_train['CompetitionDistance'].median(), inplace = True)

# %%
df_train.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance               0
# CompetitionOpenSinceMonth    268600
# CompetitionOpenSinceYear     268600
# Promo2                            0
# Promo2SinceWeek              423292
# Promo2SinceYear              423292
# PromoInterval                423292
# Year                              0
# Month                             0
# WeekOfYear                        0
# dtype: int64

# %%
# since we are not given with any information we are going ahead with replacing zero values.
df_train.CompetitionOpenSinceMonth.fillna(0, inplace = True)
df_train.CompetitionOpenSinceYear.fillna(0,inplace=True)

# %%
# Since all the promos are linked with initial promo, replacing null values with zero where initial promo does not exist.
df_train.Promo2SinceWeek.fillna(0,inplace=True)
df_train.Promo2SinceYear.fillna(0,inplace=True)
df_train.PromoInterval.fillna(0,inplace=True)

# %%
df_train.isna().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# Year                         0
# Month                        0
# WeekOfYear                   0
# dtype: int64

# %%
np.shape(df_train)
# Out:
# (844338, 20)

# %%
df_train.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4   5263        555     1      1            0
# 1      1          3   5020        546     1      1            0
# 2      1          2   4782        523     1      1            0
# 3      1          1   5011        560     1      1            0
# 4      1          0   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# ...

# %%
plt.figure(figsize=(20,10))
plt.scatter(x="CompetitionDistance",y="Sales",data=df_train,color='red')
plt.title("Sales VS CompettionDistance")
plt.xlabel("CompetitionDistance")
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize=(20,10))
plt.scatter(x="CompetitionDistance",y="Customers",data=df_train,color='green')
plt.title("Customers VS CompettionDistance")
plt.xlabel("CompetitionDistance")
plt.ylabel('customers')
# Out:
# Text(0, 0.5, 'customers')

# %%
sns.catplot(x="Assortment",y="Sales",data=df_train)# sales for different types of stores.

# %%
StoretypeXAssortment = sns.countplot(x="StoreType",hue="Assortment",order=["a","b","c","d"], data=df_train,palette=sns.color_palette("Set2", n_colors=3)).set_title("Number of Different Assortments per Store Type")
df_train.groupby(by=["StoreType","Assortment"]).Assortment.count()
# Out:
# StoreType  Assortment
# a          a             286028
#            c             171014
# b          a               6409
#            b               8209
#            c                942
# c          a              58554
#            c              54414
# d          a              93884
#            c             164884
# Name: Assortment, dtype: int64

# %%
df_train['PromoInterval'].unique()
# Out:
# array([0, 'Jan,Apr,Jul,Oct', 'Feb,May,Aug,Nov', 'Mar,Jun,Sept,Dec'],
#       dtype=object)

# %%
df_train['Assortment'].unique()
# Out:
# array(['a', 'c', 'b'], dtype=object)

# %%
df_train['StateHoliday'].unique()
# Out:
# array(['0', 0, 'a', 'b', 'c'], dtype=object)

# %%
df_train['SalesperCustomer']=df_train['Sales']/df_train['Customers']

# %%
df_train.groupby(by="StoreType").sum().Sales.index,df_train.groupby(by="StoreType").SalesperCustomer.mean() # store D is having move sales per customer.
# Out:
# (Index(['a', 'b', 'c', 'd'], dtype='object', name='StoreType'), StoreType
#  a     8.846296
#  b     5.133427
#  c     8.626227
#  d    11.277862
#  Name: SalesperCustomer, dtype: float64)

# %%
df_train['StateHoliday'] = df_train['StateHoliday'].astype('category')
df_train['Assortment'] = df_train['Assortment'].astype('category')
df_train['StoreType'] = df_train['StoreType'].astype('category')
df_train['PromoInterval']= df_train['PromoInterval'].astype('category')

# %%
df_train['StateHoliday_cat'] = df_train['StateHoliday'].cat.codes
df_train['Assortment_cat'] = df_train['Assortment'].cat.codes
df_train['StoreType_cat'] = df_train['StoreType'].cat.codes
df_train['PromoInterval_cat'] = df_train['PromoInterval'].cat.codes

# %%
df_train['StateHoliday_cat'] = df_train['StateHoliday_cat'].astype('float')
df_train['Assortment_cat'] = df_train['Assortment_cat'].astype('float')
df_train['StoreType_cat'] = df_train['StoreType_cat'].astype('float')
df_train['PromoInterval_cat'] = df_train['PromoInterval_cat'].astype('float')

# %%
df_train.dtypes
# Out:
# Store                           int64
# DayOfWeek                       int64
# Sales                           int64
# Customers                       int64
# Open                            int64
# Promo                           int64
# StateHoliday                 category
# SchoolHoliday                   int64
# StoreType                    category
# Assortment                   category
# CompetitionDistance           float64
# CompetitionOpenSinceMonth     float64
# CompetitionOpenSinceYear      float64
# Promo2                          int64
# Promo2SinceWeek               float64
# Promo2SinceYear               float64
# PromoInterval                category
# Year                            int64
# Month                           int64
# WeekOfYear                      int64
# SalesperCustomer              float64
# StateHoliday_cat              float64
# Assortment_cat                float64
# StoreType_cat                 float64
# PromoInterval_cat             float64
# ...

# %%
df_correlation=df_train[['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
        'SchoolHoliday',
       'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear',  'Month', 'Year',
       'StateHoliday_cat', 'Assortment_cat', 'StoreType_cat',
       'PromoInterval_cat']]

# %%
df_correlation.pop('Open')
df_corr=df_correlation.corr()
df_corr
# Out:
#                               Store  DayOfWeek     Sales  Customers     Promo  \
# Store                      1.000000   0.000343  0.007723   0.033991 -0.000015
# DayOfWeek                  0.000343   1.000000 -0.178753  -0.097266 -0.289268
# Sales                      0.007723  -0.178753  1.000000   0.823552  0.368199
# Customers                  0.033991  -0.097266  0.823552   1.000000  0.182859
# Promo                     -0.000015  -0.289268  0.368199   0.182859  1.000000
# SchoolHoliday              0.000526  -0.139319  0.038635   0.024915  0.028971
# CompetitionDistance       -0.027080   0.005540 -0.035907  -0.147858 -0.002392
# CompetitionOpenSinceMonth -0.032549  -0.000834 -0.018369  -0.021005  0.000710
# CompetitionOpenSinceYear  -0.008150  -0.001308  0.005257   0.001657  0.000987
# Promo2                     0.007728  -0.003252 -0.127556  -0.202207 -0.000316
# Promo2SinceWeek            0.010853  -0.002736 -0.058493  -0.130864 -0.000795
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_corr,cmap="YlGnBu",annot=True,linewidth=0.5)

# %%
dft=pd.read_csv('test.csv')

# %%
dft.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
df_test=pd.merge(dft,store,on="Store")

# %%
df_test.head()
# Out:
#      Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0     1      1          4  2015-09-17   1.0      1            0
# 1   857      1          3  2015-09-16   1.0      1            0
# 2  1713      1          2  2015-09-15   1.0      1            0
# 3  2569      1          1  2015-09-14   1.0      1            0
# 4  3425      1          7  2015-09-13   0.0      0            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              0         c          a               1270.0
# 1              0         c          a               1270.0
# 2              0         c          a               1270.0
# 3              0         c          a               1270.0
# 4              0         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# ...

# %%
df_test.fillna(1,inplace=True)

# %%
df_test['Open'].unique()
# Out:
# array([1., 0.])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
# Id                           41088 non-null int64
# Store                        41088 non-null int64
# DayOfWeek                    41088 non-null int64
# Date                         41088 non-null object
# Open                         41088 non-null float64
# Promo                        41088 non-null int64
# StateHoliday                 41088 non-null object
# SchoolHoliday                41088 non-null int64
# StoreType                    41088 non-null object
# Assortment                   41088 non-null object
# CompetitionDistance          41088 non-null float64
# CompetitionOpenSinceMonth    41088 non-null float64
# CompetitionOpenSinceYear     41088 non-null float64
# Promo2                       41088 non-null int64
# Promo2SinceWeek              41088 non-null float64
# Promo2SinceYear              41088 non-null float64
# ...

# %%
df_test['Date'] = pd.to_datetime(df_test['Date'], errors='coerce')

# %%
df_test=df_test.drop('Date',axis=1)

# %%
df_test['StateHoliday'] = df_test['StateHoliday'].astype('category')
df_test['StateHoliday_cat'] = df_test['StateHoliday'].cat.codes
df_test['StateHoliday_cat'] = df_test['StateHoliday_cat'].astype('float')

# %%
df_test.head()
# Out:
#      Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday StoreType  \
# 0     1      1          4   1.0      1            0              0         c
# 1   857      1          3   1.0      1            0              0         c
# 2  1713      1          2   1.0      1            0              0         c
# 3  2569      1          1   1.0      1            0              0         c
# 4  3425      1          7   0.0      0            0              0         c
#
#   Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0          a               1270.0                        9.0
# 1          a               1270.0                        9.0
# 2          a               1270.0                        9.0
# 3          a               1270.0                        9.0
# 4          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
df_test['Promo2SinceWeek'].unique()
# Out:
# array([ 1., 14., 13., 45., 40., 22.,  5., 10., 31., 37.,  9., 39., 27.,
#        18., 35., 23., 48., 36., 44., 49., 28.])

# %%
from sklearn import datasets, linear_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
X = df_train.drop('Sales', axis=1)

# %%
Y=df_train['Sales']

# %%
X
# Out:
#         Store  DayOfWeek  Customers  Open  Promo StateHoliday  SchoolHoliday  \
# 0           1          4        555     1      1            0              1
# 1           1          3        546     1      1            0              1
# 2           1          2        523     1      1            0              1
# 3           1          1        560     1      1            0              1
# 4           1          0        612     1      1            0              1
# 5           1          5        500     1      0            0              0
# 6           1          4        459     1      0            0              0
# 7           1          3        503     1      0            0              0
# 8           1          2        463     1      0            0              0
# 9           1          1        469     1      0            0              0
# 10          1          0        526     1      0            0              0
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 844338 entries, 0 to 844337
# Data columns (total 24 columns):
# Store                        844338 non-null int64
# DayOfWeek                    844338 non-null int64
# Customers                    844338 non-null int64
# Open                         844338 non-null int64
# Promo                        844338 non-null int64
# StateHoliday                 844338 non-null category
# SchoolHoliday                844338 non-null int64
# StoreType                    844338 non-null category
# Assortment                   844338 non-null category
# CompetitionDistance          844338 non-null float64
# CompetitionOpenSinceMonth    844338 non-null float64
# CompetitionOpenSinceYear     844338 non-null float64
# Promo2                       844338 non-null int64
# Promo2SinceWeek              844338 non-null float64
# Promo2SinceYear              844338 non-null float64
# PromoInterval                844338 non-null category
# ...

# %%
Xt=X.drop(['SchoolHoliday','StateHoliday','StoreType','Assortment','PromoInterval'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(Xt, Y, test_size=0.33, random_state=45)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=10, 
                             criterion='mse', 
                             max_depth=5, 
                             min_samples_split=2, 
                             min_samples_leaf=1, 
                             min_weight_fraction_leaf=0.0, 
                             max_features='auto', 
                             max_leaf_nodes=None, 
                             min_impurity_decrease=0.0, 
                             min_impurity_split=None, 
                             bootstrap=True, 
                             oob_score=False,
                             n_jobs=4,
                             random_state=31, 
                             verbose=0, 
                             warm_start=False)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#            oob_score=False, random_state=31, verbose=0, warm_start=False)

# %%
pred=rfr.predict(X_test)

# %%
rfr.score(X_test, y_test)
# Out:
# 0.9345948982428376

# %%
mse = mean_squared_error(pred, y_test)
mse
# Out:
# 628566.8601708954

# %%
print(np.sqrt(mse)) # root mean squared error  for the model.
# Out:
# 792.8220860766276

# %%
dfp=pd.DataFrame(pred)

# %%
dfp.describe() # checking the min and max values to see the scales.
# Out:
#                    0
# count  278632.000000
# mean     6953.191723
# std      2964.328074
# min      2173.025678
# 25%      4714.956052
# 50%      6702.278495
# 75%      8354.913023
# max     25560.276813

# %%
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-3c9504a79c54> in <module>
# ----> 1 feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
#
# NameError: name 'feature_list' is not defined

# %%
feature_importances = pd.DataFrame(rfr.feature_importances_,
                                   index = Xt.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

# %%
feature_importances

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
reg = linear_model.LinearRegression()
reg_V2 = reg.fit(X_train, y_train)
pred1 = reg_V2.predict(X_test)

# %%
pred1

# %%
mse = mean_squared_error(pred1, y_test)
print(np.sqrt(mse))

# %%
reg.score(X_test, y_test)

# %%
pred1[:5]

# %%
X.info()

# %%
Xt.head()

# %%
np.shape(Xt)

# %%
dfnew=Xt

# %%
Xtnew=dfnew[['Assortment_cat','Month','Customers','Promo','StateHoliday_cat']] # choosing features based on Corelation Matrix.

# %%
Xtnew.head()

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(Xtnew, Y, test_size=0.33, random_state=45)

# %%
Y

# %%
np.shape(Xtnew)

# %%
np.shape(Y)

# %%
np.shape(X_train1)

# %%
np.shape(y_train1)

# %%
from sklearn.linear_model import LinearRegression
reg1 = LinearRegression().fit(X_train1, y_train1)

# %%
pred2 = reg1.predict(X_test1)

# %%
pred2

# %%
print(np.shape(X_test1))
print(np.shape(pred2))
print(np.shape(y_test1))

# %%
mse = mean_squared_error(pred2, y_test1)
print(mse)
print(np.sqrt(mse))

# %%
Y_test = y_test1[:, np.newaxis]
Y_test1 = np.array(Y_test)
print(Y_test1[:5])
Pred2 = pred2[:, np.newaxis]
print(Pred2[:5])

# %%
print('Here are the predictions for the final value:')
print(Y_test1[-1])
print(Pred2[-1])

# %%
reg1.score(X_test1, y_test1)

# %%
print(np.shape(X_test1))
print(np.shape(y_test1))
print(np.shape(pred2))

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42)

xgb_model.fit(X_train1, y_train1)

# %%
y_pred = xgb_model.predict(X_test1)

# %%
y_pred

# %%
np.shape(y_pred)

# %%
np.shape(y_test1)

# %%
mse=mean_squared_error(y_test1, y_pred)
print(np.sqrt(mse))

# %%
xgb.plot_importance(xgb_model)
